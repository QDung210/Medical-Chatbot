# %%
# !pip install --upgrade langchain langchain-community
# !pip install sentence-transformers torch
# !pip install -qU langchain-text-splitters  
# !pip install --upgrade --quiet qdrant-client 
# !pip install pandas
# !pip install matplotlib
# !pip install tqdm
# Out:
# Collecting langchain
#   Downloading langchain-0.2.17-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.9 MB/s eta 0:00:01
# Collecting langchain-community
#   Downloading langchain_community-0.2.19-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 54.4 MB/s eta 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 123.7 MB/s eta 0:00:01
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 116.5 MB/s eta 0:00:01
# Collecting numpy<2,>=1; python_version < "3.12"
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 82.5 MB/s eta 0:00:01
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Collecting PyYAML>=5.3
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#      |████████████████████████████████| 746 kB 83.5 MB/s eta 0:00:01
# Collecting langchain-core<0.3.0,>=0.2.43
#   Downloading langchain_core-0.2.43-py3-none-any.whl (397 kB)
#      |████████████████████████████████| 397 kB 55.5 MB/s eta 0:00:01
# Collecting pydantic<3,>=1
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 37.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3,>=2 in /usr/local/lib/python3.8/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting async-timeout<5.0.0,>=4.0.0; python_version < "3.11"
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting SQLAlchemy<3,>=1.4
#   Downloading sqlalchemy-2.0.41-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 113.2 MB/s eta 0:00:01
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 79.3 MB/s eta 0:00:01
# Collecting attrs>=17.3.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.5 MB/s s eta 0:00:01
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
#      |████████████████████████████████| 319 kB 101.3 MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 105.2 MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting orjson<4.0.0,>=3.9.14; platform_python_implementation != "PyPy"
#   Downloading orjson-3.10.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 108.8 MB/s eta 0:00:01
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.9 MB/s s eta 0:00:01
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 2.2 MB/s s eta 0:00:01
# Collecting packaging<25,>=23.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.9 MB/s s eta 0:00:01
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.7 in /usr/local/lib/python3.8/dist-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (4.13.2)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 69.7 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2->langchain) (2025.4.26)
# Collecting greenlet>=1; python_version < "3.14" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))))
#   Downloading greenlet-3.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (650 kB)
#      |████████████████████████████████| 650 kB 56.6 MB/s eta 0:00:01
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 20.0 MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      |████████████████████████████████| 213 kB 81.1 MB/s eta 0:00:01
# Collecting anyio
#   Downloading anyio-4.5.2-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 24.3 MB/s eta 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 24.5 MB/s  eta 0:00:01
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.2; python_version < "3.11"
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: aiohappyeyeballs, frozenlist, attrs, propcache, multidict, yarl, async-timeout, aiosignal, aiohttp, orjson, pydantic-core, annotated-types, pydantic, requests-toolbelt, sniffio, exceptiongroup, anyio, h11, httpcore, httpx, langsmith, numpy, packaging, PyYAML, tenacity, jsonpointer, jsonpatch, langchain-core, langchain-text-splitters, greenlet, SQLAlchemy, langchain, marshmallow, mypy-extensions, typing-inspect, dataclasses-json, langchain-community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 0.4.15
#     Not uninstalling greenlet at /usr/lib/python3/dist-packages, outside environment /usr
#     Can't uninstall 'greenlet'. No files were found to uninstall.
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.41 aiohappyeyeballs-2.4.4 aiohttp-3.10.11 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.5.2 async-timeout-4.0.3 attrs-25.3.0 dataclasses-json-0.6.7 exceptiongroup-1.3.0 frozenlist-1.5.0 greenlet-3.1.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.17 langchain-community-0.2.19 langchain-core-0.2.43 langchain-text-splitters-0.2.4 langsmith-0.1.147 marshmallow-3.22.0 multidict-6.1.0 mypy-extensions-1.1.0 numpy-1.24.4 orjson-3.10.15 packaging-24.2 propcache-0.2.0 pydantic-2.10.6 pydantic-core-2.27.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-8.5.0 typing-inspect-0.9.0 yarl-1.15.2
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 1.8 MB/s eta 0:00:01
# Collecting torch
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#      |████████████████████████████████| 797.1 MB 27 kB/s s eta 0:00:013
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (4.67.1)
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
#      |████████████████████████████████| 512 kB 33.9 MB/s eta 0:00:01
# Collecting Pillow
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 30.5 MB/s eta 0:00:01
# Collecting scipy
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 19.5 MB/s eta 0:00:01     |██████████████████████████▋     | 28.7 MB 19.5 MB/s eta 0:00:01
# Collecting transformers<5.0.0,>=4.41.0
#   Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#      |████████████████████████████████| 10.0 MB 22.9 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 8.6 MB/s eta 0:00:011    |██▊                             | 931 kB 17.3 MB/s eta 0:00:01
# Collecting triton==3.0.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13"
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#      |████████████████████████████████| 209.4 MB 7.0 MB/s eta 0:00:01
# Collecting nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      |████████████████████████████████| 56.5 MB 5.5 MB/s eta 0:00:01
# Collecting nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 4.3 MB/s eta 0:00:01
# Collecting nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      |████████████████████████████████| 99 kB 6.4 MB/s eta 0:00:011
# Collecting nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      |████████████████████████████████| 823 kB 6.5 MB/s eta 0:00:01
# Collecting nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      |████████████████████████████████| 176.2 MB 5.5 MB/s eta 0:00:01
# Collecting sympy
#   Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 6.8 MB/s eta 0:00:01
# Collecting fsspec
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      |████████████████████████████████| 193 kB 8.1 MB/s eta 0:00:01
# Collecting nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      |████████████████████████████████| 410.6 MB 5.2 MB/s eta 0:00:01
# Collecting nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      |████████████████████████████████| 124.2 MB 5.7 MB/s eta 0:00:01
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 6.2 MB/s eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      |████████████████████████████████| 23.7 MB 5.0 MB/s eta 0:00:01
# Collecting nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      |████████████████████████████████| 664.8 MB 22 kB/s  eta 0:00:01     |████████████████████▌           | 425.0 MB 4.7 MB/s eta 0:00:51
# Collecting nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      |████████████████████████████████| 121.6 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch) (3.16.1)
# Collecting nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      |████████████████████████████████| 196.0 MB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from torch) (4.13.2)
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 6.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Collecting hf-xet<2.0.0,>=1.1.2; platform_machine == "x86_64" or platform_machine == "amd64" or platform_machine == "arm64" or platform_machine == "aarch64"
#   Downloading hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy->sentence-transformers) (1.24.4)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (785 kB)
#      |████████████████████████████████| 785 kB 6.3 MB/s eta 0:00:01
# Collecting tokenizers<0.21,>=0.20
#   Downloading tokenizers-0.20.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 2.5 MB/s eta 0:00:01
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#      |████████████████████████████████| 471 kB 5.3 MB/s eta 0:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 5.2 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 5.4 MB/s eta 0:00:01
# Collecting nvidia-nvjitlink-cu12
#   Downloading nvidia_nvjitlink_cu12-12.9.41-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#      |████████████████████████████████| 39.7 MB 5.7 MB/s eta 0:00:01
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Installing collected packages: triton, nvidia-curand-cu12, nvidia-cuda-cupti-cu12, nvidia-nvtx-cu12, nvidia-cuda-runtime-cu12, nvidia-nccl-cu12, mpmath, sympy, fsspec, nvidia-cublas-cu12, nvidia-nvjitlink-cu12, nvidia-cusparse-cu12, nvidia-cusolver-cu12, MarkupSafe, jinja2, nvidia-cuda-nvrtc-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, networkx, torch, hf-xet, huggingface-hub, Pillow, scipy, regex, tokenizers, safetensors, transformers, joblib, threadpoolctl, scikit-learn, sentence-transformers
# Successfully installed MarkupSafe-2.1.5 Pillow-10.4.0 fsspec-2025.3.0 hf-xet-1.1.2 huggingface-hub-0.32.3 jinja2-3.1.6 joblib-1.4.2 mpmath-1.3.0 networkx-3.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.9.41 nvidia-nvtx-cu12-12.1.105 regex-2024.11.6 safetensors-0.5.3 scikit-learn-1.3.2 scipy-1.10.1 sentence-transformers-3.2.1 sympy-1.13.3 threadpoolctl-3.5.0 tokenizers-0.20.3 torch-2.4.1 transformers-4.46.3 triton-3.0.0
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from pandas) (1.24.4)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 74.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 87.8 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in ./.local/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tzdata, pytz, pandas
# Successfully installed pandas-2.0.3 pytz-2025.2 tzdata-2025.2
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 1.9 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 85.0 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 105.0 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: numpy<2,>=1.20 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      |████████████████████████████████| 301 kB 84.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (10.4.0)
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 103.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in ./.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in ./.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.20.2)
# Installing collected packages: kiwisolver, pyparsing, cycler, contourpy, importlib-resources, fonttools, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 pyparsing-3.1.4
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.67.1)
# Collecting pyarrow
#   Downloading pyarrow-17.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.0 MB)
#      |████████████████████████████████| 40.0 MB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from pyarrow) (1.24.4)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-17.0.0

# %%
import json
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
from typing import List, Dict
from tqdm import tqdm
import pyarrow.parquet as pq
import pyarrow as pa
import os
import gc
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Qdrant 
from langchain.schema import Document
import warnings
warnings.filterwarnings("ignore")

# %%
if torch.cuda.is_available():
    print("GPU is available")
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("GPU is NOT available")
# Out:
# GPU is available
# GPU name: NVIDIA GeForce RTX 4090

# %% [markdown]
# # 1. Chunk

# %%
# Tạo text splitter với cấu hình có thể điều chỉnh
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200,
    chunk_overlap=150,
    length_function=len,
    separators=[
        "\n\n",
        "\n1. ", "\n2. ", "\n3. ", "\n4. ", "\n5. ",
        "\na) ", "\nb) ", "\nc) ", "\nd) ", "\ne) ",
        "\n- ", "\n• ", "\n* ",
        "\n",
        ". ",
        " ",
        ""
    ]
)

# %%
def chunk_json_content(data: List[Dict], content_field: str = "content") -> List[Dict]:
    chunked_data = []

    for item in tqdm(data, desc="🔪 Chunking data"):
        if content_field not in item:
            chunked_data.append(item)
            continue

        content = item[content_field]

        if not content or content.strip() == "":
            chunked_data.append(item)
            continue

        chunks = text_splitter.split_text(content)

        for chunk in chunks:
            new_item = item.copy()
            new_item[content_field] = chunk
            chunked_data.append(new_item)

    return chunked_data

# %%
with open(r"/root/df.json", "r") as f:
    try:
        data = json.load(f)
    except json.JSONDecodeError as e:
        print("Lỗi JSON:", e)

# %%
# Tạo DataFrame từ dữ liệu JSON
df = pd.DataFrame(data)
# Tách riêng theo loại dữ liệu
df_article = df[df['type'] == 'article'].copy()
print(f"Số lượng bài viết (article): {len(df_article)}")
df_qa = df[df['type'] == 'qa'].copy()
print(f"Số lượng hỏi đáp (qa): {len(df_qa)}")
# Out:
# Số lượng bài viết (article): 21359
# Số lượng hỏi đáp (qa): 14181

# %%
df_article = df_article.to_dict('records')
df_qa = df_qa.to_dict('records')

# %%
# Thực hiện chunking cho articles
print("\nBắt đầu chunking articles...")
chunked_data = chunk_json_content(df_article, content_field="content")
print(f"\nKết quả chunking:")
print(f"   - Trước chunking: {len(df_article)} articles")
print(f"   - Sau chunking: {len(chunked_data)} chunks")
# Out:
# Bắt đầu chunking articles...
# 🔪 Chunking data: 100%|██████████| 21359/21359 [00:02<00:00, 8518.53it/s]
# Kết quả chunking:
#    - Trước chunking: 21359 articles
#    - Sau chunking: 149674 chunks

# %%
print(f"   - Tăng thêm: {len(chunked_data) - len(df_article)} chunks")

# Tính toán thống kê độ dài
original_lengths = [len(item.get('content', '')) for item in df_article]
chunk_lengths = [len(item.get('content', '')) for item in chunked_data]

print(f"\n Thống kê độ dài:")
print(f"   - Độ dài trung bình gốc: {sum(original_lengths)/len(original_lengths):.0f} ký tự")
print(f"   - Độ dài trung bình chunk: {sum(chunk_lengths)/len(chunk_lengths):.0f} ký tự")
print(f"   - Độ dài chunk max: {max(chunk_lengths)} ký tự")
print(f"   - Độ dài chunk min: {min(chunk_lengths)} ký tự")
# Out:
#    - Tăng thêm: 128315 chunks
#
#  Thống kê độ dài:
#    - Độ dài trung bình gốc: 5466 ký tự
#    - Độ dài trung bình chunk: 795 ký tự
#    - Độ dài chunk max: 1200 ký tự
#    - Độ dài chunk min: 8 ký tự

# %%
filtered_data = [item for item in chunked_data if len(item["content"].strip()) >= 20]
print(f"Số lượng item sau khi lọc: {len(filtered_data)}")
# Out:
# Số lượng item sau khi lọc: 149650

# %%
# Lưu vào file JSON
with open("filtered_data.json", "w", encoding="utf-8") as f:
    json.dump(filtered_data, f, ensure_ascii=False, indent=2)

print("Đã lưu filtered_data vào file 'filtered_data.json'")
# Out:
# Đã lưu filtered_data vào file 'filtered_data.json'

# %%
for i, item in enumerate(filtered_data[:10]):
    print(i)
    print(item['content'])
# Out:
# 0
# Căng cơ đùi có thể coi là một trong những chấn thương rất hay gặp, đặc biệt là ở những người bệnh thường xuyên chơi thể thao. Khi căng cơ ở đùi, bệnh nhân có thể gặp cảm giác đau đớn, khó chịu và khả năng vận động của bệnh nhân cũng bị ảnh hưởng, từ đó trực tiếp làm giảm chất lượng cuộc sống hàng ngày.
# Bài viết này được viết dưới sự hướng dẫn chuyên môn của các bác sĩ thuộc khoa Chấn thương chỉnh hình & Y học thể thao Bệnh viện Đa khoa Quốc tế Vinmec.
# 1
# 1. Căng cơ đùi là như thế nào?
# Cơ đùigồm ba nhóm chính:
# Cơ tứ đầu đùi (Quadriceps): Mặt trước đùi, giúp duỗi gối.
# Cơ gân kheo (Hamstring): Mặt sau đùi, giúp gập gối.
# Cơ khép đùi (Adductors): Mặt trong đùi, giúp khép chân.
# Căng cơ đùi là tình trạng các sợi cơ bị kéo giãn quá mức, gây tổn thương từ nhẹ đến nặng, có thể dẫn đến rách cơ một phần hoặc toàn bộ.
# Chấn thương này thường xảy ra khi người bệnh hoạt động quá mức hoặc sai tư thế, đặc biệt trong các môn thể thao như bóng đá, chạy bộ, bóng rổ. Các động tác co duỗi chân đột ngột hoặc kéo dài khi đá bóng, bật nhảy, leo cầu thang cũng có thể làm cơ đùi bị căng.
# Triệu chứng phổ biến của căng cơ đùi bao gồm đau nhức đột ngột tại vùng tổn thương, sưng, bầm tím kèm theo khó khăn khi đi lại, gập duỗi chân hoặc vận động mạnh. Nếu bịcăng cơđùi, người bệnh cần nghỉ ngơi,chườm lạnhvà tập giãn cơ nhẹ nhàng để giúp phục hồi nhanh chóng, ngăn ngừa chấn thương tái phát.
# 2
# 2. Nguyên nhân nào gây ra căng cơ đùi?
# Căng cơ đùi có thể xảy ra do nhiều nguyên nhân khác nhau, từ vận động quá mức đến các vấn đề sức khỏe. Dưới đây là những nguyên nhân phổ biến:
# 2.1 Quá lạm dụng cơ đùi
# Những người chơi thể thao như nhảy xa, nhảy cao, chạy nước rút, bóng đá thường dễ bị căng cơ đùi do lặp lại các động tác co duỗi mạnh. Khi cơ đùi phải hoạt động quá mức mà không có thời gian hồi phục, các sợi cơ bị mỏi và căng giãn liên tục, làm tăng nguy cơ chấn thương.
# 2.2 Thực hiện những chuyển động quá đột ngột
# Căng cơ đùi có thể xảy ra do bệnh nhân thực hiện một số chuyển động đột ngột. Những chuyển động này khiến cơ bị kéo giãn quá mức, có thể dẫn đến rách sợi cơ, sưng, bầm tím và đau nhức dữ dội.
# 2.3 Các bệnh lý
# Một số bệnh lý có thể làm tăng nguy cơ căng cơ đùi, bao gồm:
# Thiếu hụt khoáng chất (magie, kali, canxi) gây mất cân bằng co cơ.
# Viêm gân,viêm cơ,thoái hóa cột sốnglàm suy yếu khả năng kiểm soát vận động của cơ đùi.
# Bệnh lý thần kinh ngoại biên gây rối loạn trương lực cơ, dẫn đến chuột rút hoặc căng cơ không kiểm soát.
# 2.4 Căng thẳng
# 3
# Bệnh lý thần kinh ngoại biên gây rối loạn trương lực cơ, dẫn đến chuột rút hoặc căng cơ không kiểm soát.
# 2.4 Căng thẳng
# Căng thẳng haystresscũng có khả năng gây căng cơ đùi. Lúc này, hệ thần kinh liên tục kích thích cơ bắp, khiến các sợi cơ co thắt không tự chủ, ngay cả khi không vận động. Nếu tình trạng này kéo dài, cơ đùi có thể bị co cứng quá mức, dễ dẫn đến căng cơ.
# 2.5 Mất nước gây căng cơ đùi
# Mất nước là một trong những nguyên nhân gây ra tình trạng căng cơ nói chung. Nước giữ một vai trò lớn trongquá trình trao đổi chấtcủa cơ thể, cùng với đó là đảm bảo khả năng hoạt động của các nhóm cơ. Vì thế, mất nước cũng có khả năng khiến người bệnhbị căng cơ đùi.
# 4
# 3. Triệu chứng có thể gặp
# Một số dấu hiệu và triệu chứng của tình trạng này có thể kể đến gồm:
# Bầm tím và sưng tấy kéo dài ở đùi, thậm chí có thể lan xuống bắp chân hoặc mắt cá chân.
# Khu vực bị tổn thương có cảm giác mềm khi chạm vào.
# Các cơn đau xuất hiện đột ngột và dữ dội, có thể kéo dài trong vài ngày.
# Giảm khả năng chuyển động vàyếu cơ.
# 5
# 4. Điều trị và phòng ngừa căng cơ đùi
# Để điều trị tình trạng này, bệnh nhân có thể áp dụng một số cách sau:
# Xoa bóp nhẹ nhàng để thư giãn các cơ, cải thiện cơn đau của mình.
# Dùng băng mềm, gạc hoặc đeo băng hỗ trợ đùi nhằm ép phần đùi bị căng cơ.
# Nâng cao chân bị căng cơ cao hơn so với tim.
# Không cố gắng đi lại và tập luyện, thay vào đó dành nhiều thời gian hơn để nghỉ ngơi.
# Chườm đá ở vùng bị căng cơ.
# Dùng các loạithuốc giảm đauđược kê đơn bởi bác sĩ.
# Thực hiện một số bài tập vật lý trị liệu. Sau đó, bệnh nhân có thể tăng cường tập luyện khi chân bớt đau và sưng để nhanh chóng hoạt động trở lại như bình thường.
# Nếu bị rách cơ hoàn toàn, phẫu thuật có thể cần thiết, đặc biệt là khi tổn thương nghiêm trọng và ảnh hưởng đến chức năng vận động.
# Bên cạnh điều trị, bệnh nhân cũng nên thực hiện một số biện pháp để phòng tránh căng cơ đùi và hạn chế các tổn thương khác có thể xảy ra. Một số biện pháp mà người bệnh có thể thực hiện gồm:
# Tập thể dục thường xuyên để điều hòa và phát triển cơ bắp, hạn chế tổn thương.
# Phải luôn khởi động kỹ trước khi tập luyện bằng các động tác thích hợp.
# Giãn cơsau khi tập là cần thiết.
# Cố gắng hấp thụ đủ nước để cơ bắp hoạt động bình thường.
# 6
# Giãn cơsau khi tập là cần thiết.
# Cố gắng hấp thụ đủ nước để cơ bắp hoạt động bình thường.
# Cóchế độ ăn cân bằng và đầy đủ chất dinh dưỡngđể nuôi nấng cơ bắp, qua đó gián tiếp tránh chấn thương.
# Khi đã bị chấn thương trước đó, hãy dành thời gian để cơ bắp được lành lặn hoàn toàn trước khi quay trở lại chơi thể thao hoặc tập luyện.
# Tóm lại, có thể thấy căng cơ đùi là một trong những tình trạng chấn thương dễ gặp phải. Tình trạng này cũng gây ra nhiều sự đau đớn và khó chịu cho bệnh nhân, cũng như ảnh hưởng tới khả năng sinh hoạt của người bệnh.
# 7
# Chuột rút cơ lưng có thể gây đau đớn và ảnh hưởng đến sinh hoạt hằng ngày của người bệnh. Tuy nhiên, không phải ai cũng hiểu rõ về tình trạng này. Bài viết dưới đây sẽ cung cấp thông tin chi tiết về chuột rút cơ lưng, bao gồm các triệu chứng, nguyên nhân và biện pháp phòng ngừa, giúp người đọc có cái nhìn đầy đủ cũng như chủ động hơn trong việc chăm sóc sức khỏe.
# Bài viết này được viết dưới sự hướng dẫn chuyên môn của các bác sĩ thuộc khoa Chấn thương chỉnh hình & Y học thể thao Bệnh viện Đa khoa Quốc tế Vinmec.
# 8
# 1. Chuột rút cơ lưng là gì?
# Chuột rútcơ lưng là tình trạng co thắt cơ đột ngột ở vùng thắt lưng, gây đau nhức và khó chịu. Hiện tượng này thường liên quan đếncăng cơ, co rút dây thần kinh hoặc mất cân bằng điện giải. Khi cơ bị kích thích quá mức, chúng có thể co cứng trong thời gian ngắn, làm ảnh hưởng đến sự linh hoạt và vận động của cột sống.
# Nguyên nhân phổ biến gây chuột rút cơ lưng:
# Vận động sai tư thế.
# Thiếu hụt dinh dưỡnghoặc các yếu tố cơ học khác.
# Cách xử lý:
# Nếu nguyên nhân xuất phát từ các thói quen sinh hoạt không đúng hoặcchế độ dinh dưỡngchưa hợp lý, tình trạng này có thể được cải thiện tại nhà trong thời gian ngắn.
# Nếu chuột rút ở cơ lưng là hậu quả của chấn thương, tai nạn hoặc dohệ xương khớp suy yếu, người bệnh cần được khám và tư vấn bởi bác sĩ chuyên khoa để có phương pháp điều trị phù hợp và hiệu quả.
# 9
# 2. Triệu chứng chuột rút cơ lưng
# Chuột rút cơ lưng có thể biểu hiện khác nhau ở mỗi người nhưng thường gặp nhất là co thắt đột ngột, đau nhói hoặc cứng cơ, đặc biệt ở vùng thắt lưng.
# Tuy nhiên, các triệu chứng này có thể giống với nhiều bệnh lý cột sống và cơ xương khớp nhưthoát vị đĩa đệm,thoái hóa cột sốnghoặc căng cơ quá mức. Vì vậy, việc chẩn đoán chính xác rất quan trọng để phân biệt chuột rút cơ lưng với các vấn đề nghiêm trọng hơn, từ đó có phương pháp điều trị phù hợp.

# %% [markdown]
# # 2. Embedding

# %%
combined_data = filtered_data + df_qa
print(f"Tổng số item sau khi nối: {len(combined_data)}")
combined_data = pd.DataFrame(combined_data)
# Out:
# Tổng số item sau khi nối: 163831

# %%
combined_data
# Out:
#                                                       url  \
# 0       https://www.vinmec.com/vie/bai-viet/cang-co-du...
# 1       https://www.vinmec.com/vie/bai-viet/cang-co-du...
# 2       https://www.vinmec.com/vie/bai-viet/cang-co-du...
# 3       https://www.vinmec.com/vie/bai-viet/cang-co-du...
# 4       https://www.vinmec.com/vie/bai-viet/cang-co-du...
# ...                                                   ...
# 163826  https://www.vinmec.com/vie/bai-viet/lieu-luong...
# 163827  https://www.vinmec.com/vie/bai-viet/nen-chon-t...
# 163828  https://www.vinmec.com/vie/bai-viet/uong-thuoc...
# 163829  https://www.vinmec.com/vie/bai-viet/thoi-diem-...
# 163830  https://www.vinmec.com/vie/bai-viet/sac-thuoc-...
#
#                                                     title  \
# 0       Căng cơ đùi: Nguyên nhân và các phương pháp đi...
# 1       Căng cơ đùi: Nguyên nhân và các phương pháp đi...
# 2       Căng cơ đùi: Nguyên nhân và các phương pháp đi...
# 3       Căng cơ đùi: Nguyên nhân và các phương pháp đi...
# 4       Căng cơ đùi: Nguyên nhân và các phương pháp đi...
# ...                                                   ...
# 163826  Liều lượng uống thuốc Đông Y thế nào là hiệu q...
# 163827           Nên chọn thuốc tự sắc hay thuốc sắc sẵn?
# 163828  Uống thuốc đông y bao lâu khỏi đau dạ dày mãn ...
# 163829  Thời điểm uống thuốc Đông Y hiệu quả nhất là t...
# 163830                 Sắc thuốc Đông y thế nào cho đúng?
#
#                                                   content  \
# 0       Căng cơ đùi có thể coi là một trong những chấn...
# 1       1. Căng cơ đùi là như thế nào?\nCơ đùigồm ba n...
# 2       2. Nguyên nhân nào gây ra căng cơ đùi?\nCăng c...
# 3       Bệnh lý thần kinh ngoại biên gây rối loạn trươ...
# 4       3. Triệu chứng có thể gặp\nMột số dấu hiệu và ...
# ...                                                   ...
# 163826  tôi đang có ý định sử dụng thuốc Đông y để điề...
# 163827  tôi đang sử dụng thuốc Đông Y để điều trị mất ...
# 163828  Tôi bị đau dạ dày mãn tính, hiện đã bắt đầu sử...
# 163829  Tôi đã sử dụng thuốc Đông y được một thời gian...
# 163830  tôi bị bệnh khớp lâu năm và hiện đang điều trị...
#
#                                     tag     type
# 0       Chấn thương chỉnh hình - Y khoa  article
# 1       Chấn thương chỉnh hình - Y khoa  article
# 2       Chấn thương chỉnh hình - Y khoa  article
# 3       Chấn thương chỉnh hình - Y khoa  article
# 4       Chấn thương chỉnh hình - Y khoa  article
# ...                                 ...      ...
# 163826                  Y học cổ truyền       qa
# 163827                  Y học cổ truyền       qa
# 163828                  Y học cổ truyền       qa
# 163829                  Y học cổ truyền       qa
# 163830                  Y học cổ truyền       qa
#
# [163831 rows x 5 columns]

# %%
embeddings = HuggingFaceEmbeddings(
    model_name='strongpear/M3-retriever-MEDICAL',
    model_kwargs={'device': 'cuda'},
    encode_kwargs={'batch_size': 64}
)
# Out:
# You try to use a model that was created with version 3.3.1, however, your version is 3.2.1. This might cause unexpected behavior or errors. In that case, try to update to the latest version.

# %%
docs = [
    Document(
        page_content=f"{row['title']}\n\n{row['content']}",
        metadata={
            'url': row['url'],
            'title': row['title'],
            'tag': row['tag'],
            'type': row['type']
        }
    )
    for _, row in combined_data.iterrows()
]

# %%
qdrant_cloud_api_key='QDRANT_API_KEY'
qdrant_url='QDRANT_URL'
qdrant_cloud = Qdrant.from_documents(
    docs,
    embeddings,
    url=qdrant_url,
    prefer_grpc=True,
    api_key=qdrant_cloud_api_key,
    collection_name="medical_data"
)
# Out:
# Embedding batches:  30%|███       | 390/1280 [05:01<11:28,  1.29it/s]
# Saving file 0 with 50048 records...
# ✅ Saved embedded_data/embeddings_part_0.parquet - Size: 324.5 MB
# Embedding batches:  61%|██████    | 781/1280 [10:10<06:25,  1.30it/s]
# Saving file 1 with 50048 records...
# ✅ Saved embedded_data/embeddings_part_1.parquet - Size: 324.3 MB
# Embedding batches:  92%|█████████▏| 1172/1280 [15:27<02:31,  1.40s/it]
# Saving file 2 with 50048 records...
# ✅ Saved embedded_data/embeddings_part_2.parquet - Size: 324.1 MB
# Embedding batches: 100%|██████████| 1280/1280 [18:59<00:00,  1.12it/s]
